# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
# img_bgr = cv2.imread("images/pattern_detection/image.jpg")
# img_gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)

# img_template = cv2.imread("images/pattern_detection/patern.jpg")

# orb = cv2.ORB_create()

# kp1, descriptor1 = orb.detectAndCompute(img_template, None)
# kp2, descriptor2 = orb.detectAndCompute(img_bgr, None)

# bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

# matches = bf.match(descriptor1, descriptor2)
# matches = sorted(matches, key=lambda x:x.distance)

# img_out = cv2.drawMatches(img_bgr, kp2, img_template, kp1, matches[:10], None, flags=2)
# plt.imshor(img_out)
# plt.show()

import cv2
import matplotlib.pyplot as plt

# خواندن تصاویر
img_bgr = cv2.imread("images/pattern_detection/image.jpg")
img_template = cv2.imread("images/pattern_detection/patern.jpg")

# تبدیل تصاویر به سیاه و سفید (گری‌اسکیل)
img_gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
template_gray = cv2.cvtColor(img_template, cv2.COLOR_BGR2GRAY)

# ایجاد شیء ORB
orb = cv2.ORB_create(nfeatures=500, scaleFactor=1.2, nlevels=13)

# یافتن نقاط کلیدی و توصیفگرها
kp1, descriptor1 = orb.detectAndCompute(template_gray, None)
kp2, descriptor2 = orb.detectAndCompute(img_gray, None)

# ایجاد matcher
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

# پیدا کردن تطابق‌ها
matches = bf.match(descriptor1, descriptor2)
matches = sorted(matches, key=lambda x:x.distance)

# رسم تطابق‌ها
img_out = cv2.drawMatches(img_template, kp1, img_bgr, kp2, matches[:10], None, flags=2)

# تبدیل تصویر از BGR به RGB برای نمایش درست در matplotlib
img_out_rgb = cv2.cvtColor(img_out, cv2.COLOR_BGR2RGB)

# نمایش نتیجه
plt.figure(figsize=(15,5))
plt.imshow(img_out_rgb)
plt.axis('off')
plt.show()
